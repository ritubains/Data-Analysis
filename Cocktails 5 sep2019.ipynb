# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('hotaling_cocktails - Cocktails.csv')

# %%
data
# Out:
#                  Cocktail Name            Bartender           Bar/Company  \
# 0               Flor de Amaras       Kelly McCarthy                   NaN
# 1              The Happy Place    Elizabeth Montana       Forgery & Verso
# 2       Bon Voyage Pisco Punch          Jon Morales                   NaN
# 3    Still Life of a Pineapple      Daniel Braganca               Backbar
# 4          The Bittered Valley           Nik Virrey                   NaN
# ..                         ...                  ...                   ...
# 682         The Negroni Bianco                  NaN                   NaN
# 683           Match Grip Julep       Jarred Weigand           Death & Co.
# 684             The Dry Cruise  Jacyara de Oliveira  Rob Roy, The Hideout
# 685                   Red Hook     Patrick Halloran         Henrietta Red
# 686                 Union Jack           Jason Patz      Union Lodge No.1
#
#           Location                                        Ingredients  \
# ...

# %%
data.columns
# Out:
# Index(['Cocktail Name', 'Bartender', 'Bar/Company', 'Location', 'Ingredients',
#        'Garnish', 'Glassware', 'Preparation', 'Notes'],
#       dtype='object')

# %%
data
# Out:
# 6183

# %%
data.isnull().sum()
# Out:
# Cocktail Name      0
# Bartender        235
# Bar/Company      417
# Location         345
# Ingredients        0
# Garnish          164
# Glassware        202
# Preparation       45
# Notes            536
# dtype: int64

# %%
data_cut=data[['Cocktail Name','Ingredients','Garnish','Preparation','Glassware','Location','Bar/Company']]

# %%
data_cut
# Out:
#                  Cocktail Name  \
# 0               Flor de Amaras
# 1              The Happy Place
# 2       Bon Voyage Pisco Punch
# 3    Still Life of a Pineapple
# 4          The Bittered Valley
# ..                         ...
# 682         The Negroni Bianco
# 683           Match Grip Julep
# 684             The Dry Cruise
# 685                   Red Hook
# 686                 Union Jack
#
#                                            Ingredients  \
# 0    1.5 oz Mezcal, 1 oz Hibiscus Simple Syrup*, .5...
# 1    2 oz Junipero Gin, .75 oz House-made Cranberry...
# 2    1500 ml BarSol Selecto Italia Pisco, 750 ml Le...
# 3    1.5 oz BarSol Primero Quebranta Pisco, .75 oz ...
# 4    1.25 oz Luxardo Maraschino Liqueur, 4 drops Ac...
# ..                                                 ...
# 682  1.5 oz Luxardo Bitter Bianco, .75 oz Tempus Fu...
# 683  1.5 oz H by HINE, .5 oz Jamaican Rum, 1 tsp Ca...
# 684  1 oz Luxardo Bitter Bianco, 1 oz Lustau Oloros...
# ...

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 16.0
mosaic(data_cut, ['Cocktail Name', 'Bar/Company']);

# %%
# !pip install statsmodels
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/60/d6/e9859e68e7d6c916fdff7d8e0958a7f5813485c52fc20d061273eaaddb0c/statsmodels-0.10.1-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/29/50/a552a5aff252ae915f522e44642bb49a7b7b31677f9580cfd11bcc869976/scipy-1.3.1-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/ea/0c/5f61f1a3d4385d6bf83b83ea495068857ff8dfb89e74824c6e9eb63286d8/patsy-0.5.1-py2.py3-none-any.whl
# ...
